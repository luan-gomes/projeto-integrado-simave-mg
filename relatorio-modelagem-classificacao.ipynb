# %% [markdown]
# # Relatório de Modelagem
#
# **Universidade Estadual de Montes Claros**
# **Especialização em Ciência de Dados**
# **Disciplina:** Projeto Integrado em Ciência de Dados
# **Docente:** Dra. Luciana Balieiro Cosme
# **Alunos:**
# *  Luan Silva Gomes
# *  Mateus Nobre Silva Almeida
# *  Paulo Matheus Mendes
#
# **Projeto:** Predizer o desempenho em Língua Portuguesa e Matemática, do 5º e 9º ano do Ensino Fundamental, das escolas Estaduais e Municipais do estado de Minas Gerais, utilizando a série histórica de 2015-2025 disponível no Portal das Avaliações Educacionais de Minas Gerais, para que Instituições e pessoas interessadas possam tomar medidas e criar políticas com maior eficiência a fim de melhorar esses indicadores.
#
# **Objetivo:** Neste trabalho serão desenvolvidos e avaliados modelos de classificação utilizando os dados educacionais do SIMAVE. O processo será dividido em preparação dos dados, criação de um modelo inicial, realização de experimentos, escolha do modelo final, análise dos erros e apresentação das limitações encontradas.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import re

# %% [markdown]
# ## 1. Preparação dos dados
#
# Nesta etapa, as bases dos diferentes anos serão carregadas e organizadas em um único conjunto de dados. Também serão realizados os tratamentos necessários para deixar as informações prontas para a criação e avaliação dos modelos de classificação.

# %%
anos = [2015, 2016, 2017, 2019, 2021, 2022, 2023, 2024]


colunas14 = [
    "tipo", "codigo_regional", "regional", "codigo_municipio",
    "municipio", "codigo_escola", "escola", "edicao", "rede",
    "etapa", "disciplina", "descritor_nome",
    "descritor_descricao", "acerto"
]


colunas15 = [
    "tipo", "codigo_regional", "regional", "codigo_municipio",
    "municipio", "codigo_escola", "escola", "edicao", "rede",
    "codigo_etapa", "etapa", "disciplina", "descritor_nome",
    "descritor_descricao", "acerto"
]

# %% [markdown]
# ### Carregamento e união das bases
#
# As bases dos anos selecionados foram carregadas individualmente e, em seguida, reunidas em um único conjunto de dados. Para reduzir o tamanho da base e facilitar a etapa de modelagem, foram mantidas apenas as variáveis que poderão ser utilizadas na construção e avaliação dos modelos.

# %%
bases = []


colunas_modelagem = [
   "Ano",
    "rede",
    "etapa",
    "disciplina",
    "descritor_nome",
    "descritor_descricao",
    "acerto"
]

caminho_dados = Path(".")
padrao_arquivos = "DESCRITORES-*-ESCOLA-REDE-*.csv"

arquivos_csv = sorted(caminho_dados.glob(padrao_arquivos))
arquivos_csv = [
    arquivo
    for arquivo in arquivos_csv
    if any(str(ano) in arquivo.name for ano in anos)
]

if not arquivos_csv:
    raise FileNotFoundError(
        "Nenhum arquivo CSV encontrado no diretório atual com o padrão "
        "DESCRITORES-*-ESCOLA-REDE-*.csv"
    )


def extrair_ano(nome_arquivo):
    anos_texto = "|".join(str(ano) for ano in anos)
    resultado = re.search(anos_texto, nome_arquivo)
    
    if resultado is None:
        raise ValueError(f"Não foi possível identificar o ano no arquivo: {nome_arquivo}")
    
    return int(resultado.group())


def ler_csv_descritores(caminho_csv):   
    return pd.read_csv(
        caminho_csv,
        skiprows=3,
    )


for arquivo in arquivos_csv:
    
    ano = extrair_ano(arquivo.name)
    
    print(f"Carregando a base de {ano}: {arquivo.name}...")
    
    df = ler_csv_descritores(arquivo)

    
    if df.shape[1] == 14:
        df.columns = colunas14
        
    elif df.shape[1] == 15:
        df.columns = colunas15
        
    else:
        raise ValueError(
            f"O arquivo {arquivo.name} possui {df.shape[1]} colunas. "
            "Eram esperadas 14 ou 15 colunas."
        )

    
    df["Ano"] = ano

    
    df = df[colunas_modelagem]

    
    bases.append(df)

dados = pd.concat(
    bases,
    ignore_index=True
)

print("\nBases carregadas com sucesso!")
print("Quantidade de registros:", dados.shape[0])
print("Quantidade de variáveis:", dados.shape[1])
# Out:
# Carregando a base de 2015: DESCRITORES-2015-ESCOLA-REDE-ESTADUAL.csv...
# Carregando a base de 2015: DESCRITORES-2015-ESCOLA-REDE-MUNICIAPAL.csv...
# Carregando a base de 2016: DESCRITORES-2016-ESCOLA-REDE-ESTADUAL.csv...
# /var/folders/8j/n7wr3h9n5s37vm_t5bw87vdw0000gn/T/ipykernel_21083/226538580.py:42: DtypeWarning: Columns (0: % acerto) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(
# Carregando a base de 2016: DESCRITORES-2016-ESCOLA-REDE-MUNICIAPAL.csv...
# Carregando a base de 2017: DESCRITORES-2017-ESCOLA-REDE-MUNICIAPAL.csv...
# Carregando a base de 2019: DESCRITORES-2019-ESCOLA-REDE-ESTADUAL.csv...
# Carregando a base de 2019: DESCRITORES-2019-ESCOLA-REDE-MUNICIAPAL.csv...
# Carregando a base de 2021: DESCRITORES-2021-ESCOLA-REDE-ESTADUAL.csv...
# Carregando a base de 2022: DESCRITORES-2022-ESCOLA-REDE-ESTADUAL.csv...
# Carregando a base de 2022: DESCRITORES-2022-ESCOLA-REDE-MUNICIAPAL.csv...
# Carregando a base de 2023: DESCRITORES-2023-ESCOLA-REDE-ESTADUAL.csv...
# Carregando a base de 2023: DESCRITORES-2023-ESCOLA-REDE-MUNICIAPAL.csv...
# Carregando a base de 2024: DESCRITORES-2024-ESCOLA-REDE-ESTADUAL.csv...
# Carregando a base de 2024: DESCRITORES-2024-ESCOLA-REDE-MUNICIAPAL.csv...
#
# Bases carregadas com sucesso!
# Quantidade de registros: 5569759
# Quantidade de variáveis: 7

# %% [markdown]
# ###### Verificação inicial dos dados
#
# Após a união das bases, foi realizada uma verificação inicial para observar a estrutura do conjunto de dados, os tipos das variáveis e alguns exemplos dos registros carregados.

# %%
dados.head()
# Out:
#     Ano      rede      etapa         disciplina descritor_nome  \
# 0  2015  ESTADUAL  7º ANO EF  LINGUA PORTUGUESA            D01
# 1  2015  ESTADUAL  7º ANO EF  LINGUA PORTUGUESA            D02
# 2  2015  ESTADUAL  7º ANO EF  LINGUA PORTUGUESA            D03
# 3  2015  ESTADUAL  7º ANO EF  LINGUA PORTUGUESA            D04
# 4  2015  ESTADUAL  7º ANO EF  LINGUA PORTUGUESA            D05
#
#                                  descritor_descricao acerto
# 0  IDENTIFICAR O TEMA OU O SENTIDO GLOBAL DE UM T...     65
# 1       LOCALIZAR INFORMACOES EXPLICITAS EM UM TEXTO     70
# 2                    INFERIR INFORMACOES EM UM TEXTO     61
# 3  INFERIR O SENTIDO DE UMA PALAVRA OU EXPRESSAO ...     64
# 4      DISTINGUIR UM FATO DE UMA OPINIAO EM UM TEXTO     46

# %%
dados.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5569759 entries, 0 to 5569758
# Data columns (total 7 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   Ano                  int64
#  1   rede                 str
#  2   etapa                str
#  3   disciplina           str
#  4   descritor_nome       str
#  5   descritor_descricao  str
#  6   acerto               object
# dtypes: int64(1), object(1), str(5)
# memory usage: 297.5+ MB

# %% [markdown]
# ### Verificação das etapas e disciplinas
#
# Antes da aplicação dos filtros, foram verificados os nomes utilizados nas bases para representar as etapas de ensino e as disciplinas. Essa conferência evita a perda de registros causada por diferenças na escrita das categorias.

# %%
dados["etapa"].value_counts()
# Out:
# etapa
# 5º ANO EF    1432536
# 9º ANO EF    1420761
# 3º ANO EM    1017357
# 2º ANO EF     842112
# 3º ANO EF     449617
# 7º ANO EF     287584
# 1º ANO EM     119758
# Name: count, dtype: int64

# %%
dados["disciplina"].value_counts()
# Out:
# disciplina
# MATEMATICA           2734768
# LINGUA PORTUGUESA    1996319
# Matemática            549722
# Língua Portuguesa     278402
# ESCRITA                10514
# Name: count, dtype: int64

# %% [markdown]
# ### Padronização e seleção dos dados
#
# Foram padronizados os nomes das etapas, disciplinas e redes de ensino para evitar que diferenças de letras maiúsculas, minúsculas, acentuação ou variações de escrita fossem consideradas como categorias diferentes. Em seguida, foram selecionados os registros das redes municipal e estadual referentes ao 5º e ao 9º ano do Ensino Fundamental, nas disciplinas de Matemática e Língua Portuguesa.

# %%
import unicodedata

def padronizar_texto(valor):
    
    if pd.isna(valor):
        return valor
    
    texto = str(valor).strip().upper()
    
    texto = "".join(
        caractere
        for caractere in unicodedata.normalize("NFD", texto)
        if unicodedata.category(caractere) != "Mn"
    )
    
    return texto


def padronizar_rede(valor):
    
    texto = padronizar_texto(valor)
    
    if pd.isna(texto):
        return texto
    
    if "MUNICIP" in texto:
        return "MUNICIPAL"
    
    if "ESTAD" in texto:
        return "ESTADUAL"
    
    return texto


dados["rede"] = dados["rede"].apply(padronizar_rede)

dados["etapa"] = dados["etapa"].apply(padronizar_texto)

dados["disciplina"] = dados["disciplina"].apply(padronizar_texto)


redes_consideradas = [
    "MUNICIPAL",
    "ESTADUAL"
]


dados_filtrados = dados[
    
    (dados["rede"].isin(redes_consideradas))
    
    & (dados["etapa"].isin([
        "5º ANO EF",
        "9º ANO EF"
    ]))
    
    & (dados["disciplina"].isin([
        "MATEMATICA",
        "LINGUA PORTUGUESA"
    ]))
    
].copy()


print("Quantidade antes do filtro:", dados.shape[0])

print("Quantidade depois do filtro:", dados_filtrados.shape[0])

print("\nRegistros por rede após o filtro:")
print(dados_filtrados["rede"].value_counts(dropna=False))
# Out:
# Quantidade antes do filtro: 5569759
# Quantidade depois do filtro: 2853297
#
# Registros por rede após o filtro:
# rede
# MUNICIPAL    1459757
# ESTADUAL     1393540
# Name: count, dtype: int64

# %% [markdown]
# ### Seleção dos conteúdos avaliados
#
# Para a modelagem, foram selecionados conteúdos considerados importantes para a aprendizagem no 5º e no 9º ano do Ensino Fundamental. Em Língua Portuguesa, foram priorizadas habilidades relacionadas à leitura e interpretação de textos. Em Matemática, foram considerados conteúdos envolvendo operações, números racionais, frações, porcentagem, proporcionalidade e interpretação de tabelas e gráficos.

# %%
# Padronização da descrição dos conteúdos

dados_filtrados["descricao_padronizada"] = (
    dados_filtrados["descritor_descricao"]
    .apply(padronizar_texto)
)

# Palavras relacionadas aos conteúdos selecionados

conteudos_portugues = (
    "LOCALIZ|INFORMAC|INFER|TEMA|ASSUNTO|"
    "FATO|OPINIAO|INTERPRET|FINALIDADE"
)

conteudos_matematica = (
    "OPERAC|NUMER|RACIONAL|FRAC|PORCENT|"
    "PROPORC|TABEL|GRAF"
)

# Seleção dos conteúdos

dados_conteudos = dados_filtrados[
    
    (
        (dados_filtrados["disciplina"] == "LINGUA PORTUGUESA")
        &
        (
            dados_filtrados["descricao_padronizada"]
            .str.contains(conteudos_portugues, na=False)
        )
    )
    
    |
    
    (
        (dados_filtrados["disciplina"] == "MATEMATICA")
        &
        (
            dados_filtrados["descricao_padronizada"]
            .str.contains(conteudos_matematica, na=False)
        )
    )
    
].copy()


print(
    "Registros antes da seleção:",
    dados_filtrados.shape[0]
)

print(
    "Registros após a seleção:",
    dados_conteudos.shape[0]
)
# Out:
# Registros antes da seleção: 2853297
# Registros após a seleção: 1247246

# %% [markdown]
# ### Conferência dos conteúdos selecionados
#
# Após a aplicação do filtro, foi realizada uma conferência dos descritores selecionados. Essa etapa permite verificar se os conteúdos encontrados correspondem às habilidades definidas para o estudo.

# %%
pd.set_option("display.max_rows", 200)
pd.set_option("display.max_colwidth", None)


descritores_selecionados = (
    dados_conteudos[
        [
            "disciplina",
            "descritor_nome",
            "descritor_descricao"
        ]
    ]
    .drop_duplicates()
    .sort_values(
        [
            "disciplina",
            "descritor_nome"
        ]
    )
    .reset_index(drop=True)
)

descritores_selecionados
# Out:
#             disciplina descritor_nome  \
# 0    LINGUA PORTUGUESA            D01
# 1    LINGUA PORTUGUESA            D01
# 2    LINGUA PORTUGUESA            D02
# 3    LINGUA PORTUGUESA            D03
# 4    LINGUA PORTUGUESA            D03
# 5    LINGUA PORTUGUESA            D04
# 6    LINGUA PORTUGUESA            D04
# 7    LINGUA PORTUGUESA            D05
# 8    LINGUA PORTUGUESA            D05
# 9    LINGUA PORTUGUESA            D06
# 10   LINGUA PORTUGUESA            D08
# 11   LINGUA PORTUGUESA            D09
# 12   LINGUA PORTUGUESA            D09
# 13   LINGUA PORTUGUESA            D10
# 14   LINGUA PORTUGUESA            D11
# 15   LINGUA PORTUGUESA            D12
# 16   LINGUA PORTUGUESA            D14
# 17   LINGUA PORTUGUESA            D15
# 18   LINGUA PORTUGUESA            D20
# 19   LINGUA PORTUGUESA            D21
# 20   LINGUA PORTUGUESA         HLP005
# 21   LINGUA PORTUGUESA         HLP007
# 22   LINGUA PORTUGUESA         HLP019
# 23   LINGUA PORTUGUESA         HLP020
# 24   LINGUA PORTUGUESA         HLP021
# 25   LINGUA PORTUGUESA         HLP024
# 26   LINGUA PORTUGUESA         HLP025
# 27   LINGUA PORTUGUESA         HLP033
# 28          MATEMATICA            D01
# 29          MATEMATICA            D03
# 30          MATEMATICA            D08
# 31          MATEMATICA            D08
# 32          MATEMATICA            D09
# 33          MATEMATICA            D10
# 34          MATEMATICA            D13
# 35          MATEMATICA            D14
# 36          MATEMATICA            D15
# 37          MATEMATICA            D16
# 38          MATEMATICA            D16
# 39          MATEMATICA            D17
# 40          MATEMATICA            D17
# 41          MATEMATICA            D18
# 42          MATEMATICA            D18
# 43          MATEMATICA       D18_SAEB
# 44          MATEMATICA            D19
# 45          MATEMATICA            D19
# 46          MATEMATICA       D19_SAEB
# 47          MATEMATICA            D20
# 48          MATEMATICA            D20
# 49          MATEMATICA       D20_SAEB
# 50          MATEMATICA            D21
# 51          MATEMATICA            D21
# 52          MATEMATICA            D22
# 53          MATEMATICA            D22
# 54          MATEMATICA            D23
# 55          MATEMATICA       D23_SAEB
# 56          MATEMATICA            D24
# 57          MATEMATICA            D24
# 58          MATEMATICA       D24_SAEB
# 59          MATEMATICA       D24_SAEB
# 60          MATEMATICA            D25
# 61          MATEMATICA            D25
# 62          MATEMATICA       D25_SAEB
# 63          MATEMATICA            D26
# 64          MATEMATICA            D26
# 65          MATEMATICA            D27
# 66          MATEMATICA            D28
# 67          MATEMATICA            D28
# 68          MATEMATICA            D29
# 69          MATEMATICA            D30
# 70          MATEMATICA            D32
# 71          MATEMATICA       D32_SAEB
# 72          MATEMATICA            D33
# 73          MATEMATICA        D33_5EF
# 74          MATEMATICA            D34
# 75          MATEMATICA            D35
# 76          MATEMATICA        D35_5EF
# 77          MATEMATICA            D36
# 78          MATEMATICA            D37
# 79          MATEMATICA            D37
# 80          MATEMATICA            D38
# 81          MATEMATICA            D38
# 82          MATEMATICA            D39
# 83          MATEMATICA            D39
# 84          MATEMATICA            D42
# 85          MATEMATICA            D43
# 86          MATEMATICA            D44
# 87          MATEMATICA            D45
# 88          MATEMATICA            D46
# 89          MATEMATICA            D47
# 90          MATEMATICA        D47_5EF
# 91          MATEMATICA            D49
# 92          MATEMATICA            D50
# 93          MATEMATICA            D51
# 94          MATEMATICA            D62
# 95          MATEMATICA            D82
# 96          MATEMATICA        D82_5EF
# 97          MATEMATICA            D83
# 98          MATEMATICA        D83_5EF
# 99          MATEMATICA            D84
# 100         MATEMATICA            D85
# 101         MATEMATICA         HMT048
# 102         MATEMATICA         HMT055
# 103         MATEMATICA         HMT056
# 104         MATEMATICA         HMT057
# 105         MATEMATICA         HMT058
# 106         MATEMATICA         HMT068
# 107         MATEMATICA         HMT069
# 108         MATEMATICA         HMT070
# 109         MATEMATICA         HMT071
# 110         MATEMATICA         HMT072
# 111         MATEMATICA         HMT073
# 112         MATEMATICA         HMT074
# 113         MATEMATICA         HMT075
# 114         MATEMATICA         HMT076
# 115         MATEMATICA         HMT087
# 116         MATEMATICA         HMT088
# 117         MATEMATICA         HMT089
# 118         MATEMATICA         HMT095
# 119         MATEMATICA         HMT098
# 120         MATEMATICA         HMT099
#
#                                                                                                                                                                                           descritor_descricao
# 0                                                                                                                                                          IDENTIFICAR O TEMA OU O SENTIDO GLOBAL DE UM TEXTO
# 1                                                                                                                                                               Localizar informações explícitas em um texto.
# 2                                                                                                                                                                LOCALIZAR INFORMACOES EXPLICITAS EM UM TEXTO
# 3                                                                                                                                                                             INFERIR INFORMACOES EM UM TEXTO
# 4                                                                                                                                                              Inferir o sentido de uma palavra ou expressão.
# 5                                                                                                                                                   INFERIR O SENTIDO DE UMA PALAVRA OU EXPRESSAO EM UM TEXTO
# 6                                                                                                                                                               Inferir uma informação implícita em um texto.
# 7                                                                                                                                                               DISTINGUIR UM FATO DE UMA OPINIAO EM UM TEXTO
# 8                                                                                                            Interpretar texto com auxílio de material gráfico diverso (propagandas, quadrinhos, foto, etc.).
# 9                                                                                                                                                                             Identificar o tema de um texto.
# 10                                                                                                                                                INTERPRETAR TEXTO QUE CONJUGA LINGUAGEM VERBAL E NAO VERBAL
# 11                                                                                                         RECONHECER DIFERENTES FORMAS DE ABORDAR UMA INFORMACAO AO COMPARAR TEXTOS QUE TRATAM DO MESMO TEMA
# 12                                                                                                                                                  Identificar a finalidade de textos de diferentes gêneros.
# 13                                                                                                         RECONHECER POSICOES DISTINTAS ENTRE DUAS OU MAIS OPINIOES RELATIVAS AO MESMO FATO OU AO MESMO TEMA
# 14                                                                                                                                                        Distinguir um fato da opinião relativa a esse fato.
# 15                                                                                                                                                  Identificar a finalidade de textos de diferentes gêneros.
# 16                                                                                                                                                        Distinguir um fato da opinião relativa a esse fato.
# 17                  Reconhecer diferentes formas de tratar uma informação na comparação de textos que tratam do mesmo tema, em função das condições em que ele foi produzido e daquelas em que será recebido.
# 18                  Reconhecer diferentes formas de tratar uma informação na comparação de textos que tratam do mesmo tema, em função das condições em que ele foi produzido e daquelas em que será recebido.
# 19                                                                                                        Reconhecer posições distintas entre duas ou mais opiniões relativas ao mesmo fato ou ao mesmo tema.
# 20                                                                                                                                                               LOCALIZAR INFORMACOES EXPLICITAS EM UM TEXTO
# 21                                                                                                                                                                            INFERIR INFORMACOES EM UM TEXTO
# 22                                                                                                                                                         IDENTIFICAR O TEMA OU O SENTIDO GLOBAL DE UM TEXTO
# 23                                                                                                                                                  INFERIR O SENTIDO DE UMA PALAVRA OU EXPRESSAO EM UM TEXTO
# 24                                                                                                                                                              DISTINGUIR UM FATO DE UMA OPINIAO EM UM TEXTO
# 25                                                                                                                                                INTERPRETAR TEXTO QUE CONJUGA LINGUAGEM VERBAL E NAO VERBAL
# 26                                                                                                         RECONHECER DIFERENTES FORMAS DE ABORDAR UMA INFORMACAO AO COMPARAR TEXTOS QUE TRATAM DO MESMO TEMA
# 27                                                                                                         RECONHECER POSICOES DISTINTAS ENTRE DUAS OU MAIS OPINIOES RELATIVAS AO MESMO FATO OU AO MESMO TEMA
# 28                                                                                                       Identificar a localização/movimentação de objeto em mapas, croquis e outras representações gráficas.
# 29                                                                                    Identificar propriedades comuns e diferenças entre figuras bidimensionais pelo número de lados, pelos tipos de ângulos.
# 30                            Resolver problema utilizando propriedades dos polígonos (soma de seus ângulos internos, número de diagonais, cálculo da medida de cada ângulo interno nos polígonos regulares).
# 31                                                                                                                                                    Estabelecer relações entre unidades de medida de tempo.
# 32                                                                                        Estabelecer relações entre o horário de início e término e/ou o intervalo da duração de um evento ou acontecimento.
# 33                                                                                        Num problema, estabelecer trocas entre cédulas e moedas do sistema monetário brasileiro, em função de seus valores.
# 34                                                         Reconhecer e utilizar características do sistema de numeração decimal, tais como agrupamentos e trocas na base 10 e princípio do valor posicional.
# 35                                                                                                                                            Identificar a localização de números naturais na reta numérica.
# 36                                                                                                                                    Reconhecer a decomposição de números naturais nas suas diversas ordens.
# 37                                                                                                                                            Identificar a localização de números inteiros na reta numérica.
# 38                                                                                                                      Reconhecer a composição e a decomposição de números naturais em sua forma polinomial.
# 39                                                                                                                                           Identificar a localização de números racionais na reta numérica.
# 40                                                                                                                                       Calcular o resultado de uma adição ou subtração de números naturais.
# 41                                                                                   Efetuar cálculos com números inteiros, envolvendo as operações (adição, subtração, multiplicação, divisão, potenciação).
# 42                                                                                                                                  Calcular o resultado de uma multiplicação ou divisão de números naturais.
# 43                                                                                           EFETUAR CALCULOS COM NUMEROS INTEIROS ENVOLVENDO AS OPERACOES ADICAO SUBTRACAO MULTIPLICACAO DIVISAO POTENCIACAO
# 44                                                         Resolver problema com números naturais, envolvendo diferentes significados das operações (adição, subtração, multiplicação, divisão, potenciação).
# 45   Resolver problema com números naturais, envolvendo diferentes significados da adição ou subtração: juntar, alteração de um estado inicial (positiva ou negativa), comparação e mais de uma transforma...
# 46                                                                 RESOLVER PROBLEMA COM NUMEROS NATURAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DAS OPERACOES ADICAO SUBTRACAO MULTIPLICACAO DIVISAO POTENCIACAO
# 47                                                                                   Resolver problema com números inteiros envolvendo as operações (adição, subtração, multiplicação, divisão, potenciação).
# 48     Resolver problema com números naturais, envolvendo diferentes significados da multiplicação ou divisão: multiplicação comparativa, ideia de proporcionalidade, configuração retangular e combinatória.
# 49                                                                                          RESOLVER PROBLEMA COM NUMEROS INTEIROS ENVOLVENDO AS OPERACOES ADICAO SUBTRACAO MULTIPLICACAO DIVISAO POTENCIACAO
# 50                                                                                                                                             Reconhecer as diferentes representações de um número racional.
# 51                                                                                                                                         Identificar diferentes representações de um mesmo número racional.
# 52                                                                                                                  Identificar fração como representação que pode estar associada a diferentes significados.
# 53                                                                                                            Identificar a localização de números racionais representados na forma decimal na reta numérica.
# 54                                                                                                                                                                          Identificar frações equivalentes.
# 55                                                                                                                                                                           IDENTIFICAR FRACOES EQUIVALENTES
# 56                Reconhecer as representações decimais dos números racionais como uma extensão do sistema de numeração decimal, identificando a existência de "ordens" como décimos, centésimos e milésimos.
# 57                                                                                                                  Identificar fração como representação que pode estar associada a diferentes significados.
# 58                                                                                                                   IDENTIFICAR FRACAO COMO REPRESENTACAO QUE PODE ESTAR ASSOCIADA A DIFERENTES SIGNIFICADOS
# 59                     RECONHECER AS REPRESENTACOES DECIMAIS DOS NUMEROS RACIONAIS COMO UMA EXTENSAO DO SISTEMA DE NUMERACAO DECIMAL IDENTIFICANDO A EXISTENCIA DE ORDENS COMO DECIMOS CENTESIMOS E MILESIMOS
# 60                                                                                    Efetuar cálculos que envolvam operações com números racionais (adição, subtração, multiplicação, divisão, potenciação).
# 61                                                                              Resolver problema com números racionais expressos na forma decimal envolvendo diferentes significados da adição ou subtração.
# 62                                                                                           EFETUAR CALCULOS QUE ENVOLVAM OPERACOES COM NUMEROS RACIONAIS ADICAO SUBTRACAO MULTIPLICACAO DIVISAO POTENCIACAO
# 63                                                                                  Resolver problema com números racionais envolvendo as operações (adição, subtração, multiplicação, divisão, potenciação).
# 64                                                                                                                                       Resolver problema envolvendo noções de porcentagem (25%, 50%, 100%).
# 65                                                                                                                                                           Ler informações e dados apresentados em tabelas.
# 66                                                                                                                                                                 Resolver problema que envolva porcentagem.
# 67                                                                                                                 Ler informações e dados apresentados em gráficos (particularmente em gráficos de colunas).
# 68                                                                                                                   Resolver problema que envolva variação proporcional, direta ou inversa, entre grandezas.
# 69                                                                                                                                                      Calcular o valor numérico de uma expressão algébrica.
# 70                                                                                   Identificar a expressão algébrica que expressa uma regularidade observada em sequências de números ou figuras (padrões).
# 71                                                                                      IDENTIFICAR A EXPRESSAO ALGEBRICA QUE EXPRESSA UMA REGULARIDADE OBSERVADA EM SEQUENCIAS DE NUMEROS OU FIGURAS PADROES
# 72                                                                                                                                                 RECONHECER CARACTERISTICAS DO SISTEMA DE NUMERACAO DECIMAL
# 73                                                                                                                                                 RECONHECER CARACTERISTICAS DO SISTEMA DE NUMERACAO DECIMAL
# 74                                                                                                                                                       CORRESPONDER NUMEROS REAIS A PONTOS DA RETA NUMERICA
# 75                                                                                                                                                                     EXECUTAR CALCULOS COM NUMEROS NATURAIS
# 76                                                                                                                                                                     EXECUTAR CALCULOS COM NUMEROS NATURAIS
# 77                                                                                                                            Resolver problema envolvendo informações apresentadas em tabelas e/ou gráficos.
# 78                                                                                                                                                                    EXECUTAR CALCULOS COM NUMEROS RACIONAIS
# 79                                                                                             Associar informações apresentadas em listas e/ou tabelas simples aos gráficos que as representam e vice-versa.
# 80                                                                                              UTILIZAR NUMEROS NATURAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DA ADICAO OU SUBTRACAO NA RESOLUCAO DE PROBLEMAS
# 81                                                                                           UTILIZAR NUMEROS NATURAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DA ADICAO OU DA SUBTRACAO NA RESOLUCAO DE PROBLEMAS
# 82                                                                                         UTILIZAR NUMEROS NATURAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DA MULTIPLICACAO OU DIVISAO NA RESOLUCAO DE PROBLEMAS
# 83                                                                                      UTILIZAR NUMEROS NATURAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DA MULTIPLICACAO OU DA DIVISAO NA RESOLUCAO DE PROBLEMAS
# 84                                                                                                                                               CORRESPONDER DIFERENTES REPRESENTACOES DE UM NUMERO RACIONAL
# 85                                                                                                                                   RECONHECER FRACAO COMO REPRESENTACAO ASSOCIADA A DIFERENTES SIGNIFICADOS
# 86                                                                 UTILIZAR NUMEROS RACIONAIS EXPRESSOS NA FORMA DECIMAL ENVOLVENDO DIFERENTES SIGNIFICADOS DA ADICAO EOU SUBTRACAO NA RESOLUCAO DE PROBLEMAS
# 87                                                                                        UTILIZAR NUMEROS RACIONAIS EXPRESSOS NA FORMA DECIMAL ENVOLVENDO MULTIPLICACAO OU DIVISAO NA RESOLUCAO DE PROBLEMAS
# 88                                                                                                      UTILIZAR NUMEROS RACIONAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DAS OPERACOES NA RESOLUCAO DE PROBLEMAS
# 89                                                                                                                                               IDENTIFICAR COMPOSICOES OU DECOMPOSICOES DE NUMEROS NATURAIS
# 90                                                                                                                                               IDENTIFICAR COMPOSICOES OU DECOMPOSICOES DE NUMEROS NATURAIS
# 91                                                                                                                                                            EXECUTAR EXPRESSOES NUMERICAS COM NUMEROS REAIS
# 92                                                                                                                                                              UTILIZAR PORCENTAGEM NA RESOLUCAO DE PROBLEMA
# 93                                                                                                               UTILIZAR RELACOES DE PROPORCIONALIDADE ENTRE DUAS OU MAIS GRANDEZAS NA RESOLUCAO DE PROBLEMA
# 94                                                                                                                                            EXECUTAR O CALCULO DO VALOR NUMERICO DE UMA EXPRESSAO ALGEBRICA
# 95                                                                                                                                             IDENTIFICAR INFORMACOES A PARTIR DE DADOS DISPOSTOS EM TABELAS
# 96                                                                                                                                             IDENTIFICAR INFORMACOES A PARTIR DE DADOS DISPOSTOS EM TABELAS
# 97                                                                                                                                                        IDENTIFICAR DADOS APRESENTADOS POR MEIO DE GRAFICOS
# 98                                                                                                                                                        IDENTIFICAR DADOS APRESENTADOS POR MEIO DE GRAFICOS
# 99                                                                                                                               UTILIZAR DADOS APRESENTADOS EM TABELAS OU GRAFICOS NA RESOLUCAO DE PROBLEMAS
# 100                                                                                                                                                        CORRESPONDER LISTAS EOU TABELAS SIMPLES A GRAFICOS
# 101                                                                                                                                              IDENTIFICAR COMPOSICOES OU DECOMPOSICOES DE NUMEROS NATURAIS
# 102                                                                                          UTILIZAR NUMEROS NATURAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DA ADICAO OU DA SUBTRACAO NA RESOLUCAO DE PROBLEMAS
# 103                                                                                     UTILIZAR NUMEROS NATURAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DA MULTIPLICACAO OU DA DIVISAO NA RESOLUCAO DE PROBLEMAS
# 104                                                                                                                                            IDENTIFICAR INFORMACOES A PARTIR DE DADOS DISPOSTOS EM TABELAS
# 105                                                                                                                                                       IDENTIFICAR DADOS APRESENTADOS POR MEIO DE GRAFICOS
# 106                                                                                                                                                RECONHECER CARACTERISTICAS DO SISTEMA DE NUMERACAO DECIMAL
# 107                                                                                                                                                      CORRESPONDER NUMEROS REAIS A PONTOS DA RETA NUMERICA
# 108                                                                                                                                                                    EXECUTAR CALCULOS COM NUMEROS NATURAIS
# 109                                                                                                                                                                   EXECUTAR CALCULOS COM NUMEROS RACIONAIS
# 110                                                                                                                                              CORRESPONDER DIFERENTES REPRESENTACOES DE UM NUMERO RACIONAL
# 111                                                                UTILIZAR NUMEROS RACIONAIS EXPRESSOS NA FORMA DECIMAL ENVOLVENDO DIFERENTES SIGNIFICADOS DA ADICAO EOU SUBTRACAO NA RESOLUCAO DE PROBLEMAS
# 112                                                                                                     UTILIZAR NUMEROS RACIONAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DAS OPERACOES NA RESOLUCAO DE PROBLEMAS
# 113                                                                                       UTILIZAR NUMEROS RACIONAIS EXPRESSOS NA FORMA DECIMAL ENVOLVENDO MULTIPLICACAO OU DIVISAO NA RESOLUCAO DE PROBLEMAS
# 114                                                                                                                                                             UTILIZAR PORCENTAGEM NA RESOLUCAO DE PROBLEMA
# 115                                                                                                                                  RECONHECER FRACAO COMO REPRESENTACAO ASSOCIADA A DIFERENTES SIGNIFICADOS
# 116                                                                                                                                                           EXECUTAR EXPRESSOES NUMERICAS COM NUMEROS REAIS
# 117                                                                                                              UTILIZAR RELACOES DE PROPORCIONALIDADE ENTRE DUAS OU MAIS GRANDEZAS NA RESOLUCAO DE PROBLEMA
# 118                                                                                                                                           EXECUTAR O CALCULO DO VALOR NUMERICO DE UMA EXPRESSAO ALGEBRICA
# 119                                                                                                                              UTILIZAR DADOS APRESENTADOS EM TABELAS OU GRAFICOS NA RESOLUCAO DE PROBLEMAS
# 120                                                                                                                                                        CORRESPONDER LISTAS EOU TABELAS SIMPLES A GRAFICOS

# %%
conteudos_portugues = (
    "LOCALIZAR INFORMACOES EXPLICITAS|"
    "INFERIR INFORMACOES|"
    "INFERIR O SENTIDO|"
    "INFORMACAO IMPLICITA|"
    "IDENTIFICAR O TEMA|"
    "SENTIDO GLOBAL|"
    "FATO.*OPINIAO|"
    "OPINIAO.*FATO|"
    "FINALIDADE DE UM TEXTO"
)

conteudos_matematica = (
    "ADICAO|"
    "SUBTRACAO|"
    "MULTIPLICACAO|"
    "DIVISAO|"
    "OPERACOES|"
    "NUMERO RACIONAL|"
    "NUMEROS RACIONAIS|"
    "FRACAO|"
    "FRACOES|"
    "PORCENTAGEM|"
    "PERCENTUAL|"
    "PROPORCIONALIDADE|"
    "PROPORCAO|"
    "\\bTABELA\\b|"
    "\\bTABELAS\\b|"
    "\\bGRAFICO\\b|"
    "\\bGRAFICOS\\b"
)

dados_conteudos = dados_filtrados[

    (
        (dados_filtrados["disciplina"] == "LINGUA PORTUGUESA")
        &
        dados_filtrados["descricao_padronizada"]
        .str.contains(conteudos_portugues, na=False, regex=True)
    )

    |

    (
        (dados_filtrados["disciplina"] == "MATEMATICA")
        &
        dados_filtrados["descricao_padronizada"]
        .str.contains(conteudos_matematica, na=False, regex=True)
    )

].copy()

print("Registros selecionados:", dados_conteudos.shape[0])
# Out:
# Registros selecionados: 833574

# %%
descritores_selecionados = (
    dados_conteudos[
        [
            "disciplina",
            "descritor_nome",
            "descritor_descricao"
        ]
    ]
    .drop_duplicates()
    .sort_values(
        [
            "disciplina",
            "descritor_nome"
        ]
    )
    .reset_index(drop=True)
)

descritores_selecionados
# Out:
#            disciplina descritor_nome  \
# 0   LINGUA PORTUGUESA            D01
# 1   LINGUA PORTUGUESA            D01
# 2   LINGUA PORTUGUESA            D02
# 3   LINGUA PORTUGUESA            D03
# 4   LINGUA PORTUGUESA            D03
# 5   LINGUA PORTUGUESA            D04
# 6   LINGUA PORTUGUESA            D04
# 7   LINGUA PORTUGUESA            D05
# 8   LINGUA PORTUGUESA            D06
# 9   LINGUA PORTUGUESA            D11
# 10  LINGUA PORTUGUESA            D14
# 11  LINGUA PORTUGUESA         HLP005
# 12  LINGUA PORTUGUESA         HLP007
# 13  LINGUA PORTUGUESA         HLP019
# 14  LINGUA PORTUGUESA         HLP020
# 15  LINGUA PORTUGUESA         HLP021
# 16         MATEMATICA            D17
# 17         MATEMATICA            D17
# 18         MATEMATICA            D18
# 19         MATEMATICA            D18
# 20         MATEMATICA       D18_SAEB
# 21         MATEMATICA            D19
# 22         MATEMATICA            D19
# 23         MATEMATICA       D19_SAEB
# 24         MATEMATICA            D20
# 25         MATEMATICA            D20
# 26         MATEMATICA       D20_SAEB
# 27         MATEMATICA            D21
# 28         MATEMATICA            D21
# 29         MATEMATICA            D22
# 30         MATEMATICA            D22
# 31         MATEMATICA            D23
# 32         MATEMATICA       D23_SAEB
# 33         MATEMATICA            D24
# 34         MATEMATICA            D24
# 35         MATEMATICA       D24_SAEB
# 36         MATEMATICA       D24_SAEB
# 37         MATEMATICA            D25
# 38         MATEMATICA            D25
# 39         MATEMATICA       D25_SAEB
# 40         MATEMATICA            D26
# 41         MATEMATICA            D26
# 42         MATEMATICA            D27
# 43         MATEMATICA            D28
# 44         MATEMATICA            D28
# 45         MATEMATICA            D36
# 46         MATEMATICA            D37
# 47         MATEMATICA            D37
# 48         MATEMATICA            D38
# 49         MATEMATICA            D38
# 50         MATEMATICA            D39
# 51         MATEMATICA            D39
# 52         MATEMATICA            D42
# 53         MATEMATICA            D43
# 54         MATEMATICA            D44
# 55         MATEMATICA            D45
# 56         MATEMATICA            D46
# 57         MATEMATICA            D50
# 58         MATEMATICA            D51
# 59         MATEMATICA            D82
# 60         MATEMATICA        D82_5EF
# 61         MATEMATICA            D83
# 62         MATEMATICA        D83_5EF
# 63         MATEMATICA            D84
# 64         MATEMATICA            D85
# 65         MATEMATICA         HMT055
# 66         MATEMATICA         HMT056
# 67         MATEMATICA         HMT057
# 68         MATEMATICA         HMT058
# 69         MATEMATICA         HMT071
# 70         MATEMATICA         HMT072
# 71         MATEMATICA         HMT073
# 72         MATEMATICA         HMT074
# 73         MATEMATICA         HMT075
# 74         MATEMATICA         HMT076
# 75         MATEMATICA         HMT087
# 76         MATEMATICA         HMT089
# 77         MATEMATICA         HMT098
# 78         MATEMATICA         HMT099
#
#                                                                                                                                                                                          descritor_descricao
# 0                                                                                                                                                         IDENTIFICAR O TEMA OU O SENTIDO GLOBAL DE UM TEXTO
# 1                                                                                                                                                              Localizar informações explícitas em um texto.
# 2                                                                                                                                                               LOCALIZAR INFORMACOES EXPLICITAS EM UM TEXTO
# 3                                                                                                                                                                            INFERIR INFORMACOES EM UM TEXTO
# 4                                                                                                                                                             Inferir o sentido de uma palavra ou expressão.
# 5                                                                                                                                                  INFERIR O SENTIDO DE UMA PALAVRA OU EXPRESSAO EM UM TEXTO
# 6                                                                                                                                                              Inferir uma informação implícita em um texto.
# 7                                                                                                                                                              DISTINGUIR UM FATO DE UMA OPINIAO EM UM TEXTO
# 8                                                                                                                                                                            Identificar o tema de um texto.
# 9                                                                                                                                                        Distinguir um fato da opinião relativa a esse fato.
# 10                                                                                                                                                       Distinguir um fato da opinião relativa a esse fato.
# 11                                                                                                                                                              LOCALIZAR INFORMACOES EXPLICITAS EM UM TEXTO
# 12                                                                                                                                                                           INFERIR INFORMACOES EM UM TEXTO
# 13                                                                                                                                                        IDENTIFICAR O TEMA OU O SENTIDO GLOBAL DE UM TEXTO
# 14                                                                                                                                                 INFERIR O SENTIDO DE UMA PALAVRA OU EXPRESSAO EM UM TEXTO
# 15                                                                                                                                                             DISTINGUIR UM FATO DE UMA OPINIAO EM UM TEXTO
# 16                                                                                                                                          Identificar a localização de números racionais na reta numérica.
# 17                                                                                                                                      Calcular o resultado de uma adição ou subtração de números naturais.
# 18                                                                                  Efetuar cálculos com números inteiros, envolvendo as operações (adição, subtração, multiplicação, divisão, potenciação).
# 19                                                                                                                                 Calcular o resultado de uma multiplicação ou divisão de números naturais.
# 20                                                                                          EFETUAR CALCULOS COM NUMEROS INTEIROS ENVOLVENDO AS OPERACOES ADICAO SUBTRACAO MULTIPLICACAO DIVISAO POTENCIACAO
# 21                                                        Resolver problema com números naturais, envolvendo diferentes significados das operações (adição, subtração, multiplicação, divisão, potenciação).
# 22  Resolver problema com números naturais, envolvendo diferentes significados da adição ou subtração: juntar, alteração de um estado inicial (positiva ou negativa), comparação e mais de uma transforma...
# 23                                                                RESOLVER PROBLEMA COM NUMEROS NATURAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DAS OPERACOES ADICAO SUBTRACAO MULTIPLICACAO DIVISAO POTENCIACAO
# 24                                                                                  Resolver problema com números inteiros envolvendo as operações (adição, subtração, multiplicação, divisão, potenciação).
# 25    Resolver problema com números naturais, envolvendo diferentes significados da multiplicação ou divisão: multiplicação comparativa, ideia de proporcionalidade, configuração retangular e combinatória.
# 26                                                                                         RESOLVER PROBLEMA COM NUMEROS INTEIROS ENVOLVENDO AS OPERACOES ADICAO SUBTRACAO MULTIPLICACAO DIVISAO POTENCIACAO
# 27                                                                                                                                            Reconhecer as diferentes representações de um número racional.
# 28                                                                                                                                        Identificar diferentes representações de um mesmo número racional.
# 29                                                                                                                 Identificar fração como representação que pode estar associada a diferentes significados.
# 30                                                                                                           Identificar a localização de números racionais representados na forma decimal na reta numérica.
# 31                                                                                                                                                                         Identificar frações equivalentes.
# 32                                                                                                                                                                          IDENTIFICAR FRACOES EQUIVALENTES
# 33               Reconhecer as representações decimais dos números racionais como uma extensão do sistema de numeração decimal, identificando a existência de "ordens" como décimos, centésimos e milésimos.
# 34                                                                                                                 Identificar fração como representação que pode estar associada a diferentes significados.
# 35                                                                                                                  IDENTIFICAR FRACAO COMO REPRESENTACAO QUE PODE ESTAR ASSOCIADA A DIFERENTES SIGNIFICADOS
# 36                    RECONHECER AS REPRESENTACOES DECIMAIS DOS NUMEROS RACIONAIS COMO UMA EXTENSAO DO SISTEMA DE NUMERACAO DECIMAL IDENTIFICANDO A EXISTENCIA DE ORDENS COMO DECIMOS CENTESIMOS E MILESIMOS
# 37                                                                                   Efetuar cálculos que envolvam operações com números racionais (adição, subtração, multiplicação, divisão, potenciação).
# 38                                                                             Resolver problema com números racionais expressos na forma decimal envolvendo diferentes significados da adição ou subtração.
# 39                                                                                          EFETUAR CALCULOS QUE ENVOLVAM OPERACOES COM NUMEROS RACIONAIS ADICAO SUBTRACAO MULTIPLICACAO DIVISAO POTENCIACAO
# 40                                                                                 Resolver problema com números racionais envolvendo as operações (adição, subtração, multiplicação, divisão, potenciação).
# 41                                                                                                                                      Resolver problema envolvendo noções de porcentagem (25%, 50%, 100%).
# 42                                                                                                                                                          Ler informações e dados apresentados em tabelas.
# 43                                                                                                                                                                Resolver problema que envolva porcentagem.
# 44                                                                                                                Ler informações e dados apresentados em gráficos (particularmente em gráficos de colunas).
# 45                                                                                                                           Resolver problema envolvendo informações apresentadas em tabelas e/ou gráficos.
# 46                                                                                                                                                                   EXECUTAR CALCULOS COM NUMEROS RACIONAIS
# 47                                                                                            Associar informações apresentadas em listas e/ou tabelas simples aos gráficos que as representam e vice-versa.
# 48                                                                                             UTILIZAR NUMEROS NATURAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DA ADICAO OU SUBTRACAO NA RESOLUCAO DE PROBLEMAS
# 49                                                                                          UTILIZAR NUMEROS NATURAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DA ADICAO OU DA SUBTRACAO NA RESOLUCAO DE PROBLEMAS
# 50                                                                                        UTILIZAR NUMEROS NATURAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DA MULTIPLICACAO OU DIVISAO NA RESOLUCAO DE PROBLEMAS
# 51                                                                                     UTILIZAR NUMEROS NATURAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DA MULTIPLICACAO OU DA DIVISAO NA RESOLUCAO DE PROBLEMAS
# 52                                                                                                                                              CORRESPONDER DIFERENTES REPRESENTACOES DE UM NUMERO RACIONAL
# 53                                                                                                                                  RECONHECER FRACAO COMO REPRESENTACAO ASSOCIADA A DIFERENTES SIGNIFICADOS
# 54                                                                UTILIZAR NUMEROS RACIONAIS EXPRESSOS NA FORMA DECIMAL ENVOLVENDO DIFERENTES SIGNIFICADOS DA ADICAO EOU SUBTRACAO NA RESOLUCAO DE PROBLEMAS
# 55                                                                                       UTILIZAR NUMEROS RACIONAIS EXPRESSOS NA FORMA DECIMAL ENVOLVENDO MULTIPLICACAO OU DIVISAO NA RESOLUCAO DE PROBLEMAS
# 56                                                                                                     UTILIZAR NUMEROS RACIONAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DAS OPERACOES NA RESOLUCAO DE PROBLEMAS
# 57                                                                                                                                                             UTILIZAR PORCENTAGEM NA RESOLUCAO DE PROBLEMA
# 58                                                                                                              UTILIZAR RELACOES DE PROPORCIONALIDADE ENTRE DUAS OU MAIS GRANDEZAS NA RESOLUCAO DE PROBLEMA
# 59                                                                                                                                            IDENTIFICAR INFORMACOES A PARTIR DE DADOS DISPOSTOS EM TABELAS
# 60                                                                                                                                            IDENTIFICAR INFORMACOES A PARTIR DE DADOS DISPOSTOS EM TABELAS
# 61                                                                                                                                                       IDENTIFICAR DADOS APRESENTADOS POR MEIO DE GRAFICOS
# 62                                                                                                                                                       IDENTIFICAR DADOS APRESENTADOS POR MEIO DE GRAFICOS
# 63                                                                                                                              UTILIZAR DADOS APRESENTADOS EM TABELAS OU GRAFICOS NA RESOLUCAO DE PROBLEMAS
# 64                                                                                                                                                        CORRESPONDER LISTAS EOU TABELAS SIMPLES A GRAFICOS
# 65                                                                                          UTILIZAR NUMEROS NATURAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DA ADICAO OU DA SUBTRACAO NA RESOLUCAO DE PROBLEMAS
# 66                                                                                     UTILIZAR NUMEROS NATURAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DA MULTIPLICACAO OU DA DIVISAO NA RESOLUCAO DE PROBLEMAS
# 67                                                                                                                                            IDENTIFICAR INFORMACOES A PARTIR DE DADOS DISPOSTOS EM TABELAS
# 68                                                                                                                                                       IDENTIFICAR DADOS APRESENTADOS POR MEIO DE GRAFICOS
# 69                                                                                                                                                                   EXECUTAR CALCULOS COM NUMEROS RACIONAIS
# 70                                                                                                                                              CORRESPONDER DIFERENTES REPRESENTACOES DE UM NUMERO RACIONAL
# 71                                                                UTILIZAR NUMEROS RACIONAIS EXPRESSOS NA FORMA DECIMAL ENVOLVENDO DIFERENTES SIGNIFICADOS DA ADICAO EOU SUBTRACAO NA RESOLUCAO DE PROBLEMAS
# 72                                                                                                     UTILIZAR NUMEROS RACIONAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DAS OPERACOES NA RESOLUCAO DE PROBLEMAS
# 73                                                                                       UTILIZAR NUMEROS RACIONAIS EXPRESSOS NA FORMA DECIMAL ENVOLVENDO MULTIPLICACAO OU DIVISAO NA RESOLUCAO DE PROBLEMAS
# 74                                                                                                                                                             UTILIZAR PORCENTAGEM NA RESOLUCAO DE PROBLEMA
# 75                                                                                                                                  RECONHECER FRACAO COMO REPRESENTACAO ASSOCIADA A DIFERENTES SIGNIFICADOS
# 76                                                                                                              UTILIZAR RELACOES DE PROPORCIONALIDADE ENTRE DUAS OU MAIS GRANDEZAS NA RESOLUCAO DE PROBLEMA
# 77                                                                                                                              UTILIZAR DADOS APRESENTADOS EM TABELAS OU GRAFICOS NA RESOLUCAO DE PROBLEMAS
# 78                                                                                                                                                        CORRESPONDER LISTAS EOU TABELAS SIMPLES A GRAFICOS

# %% [markdown]
# ### Verificação da variável de desempenho
#
# A variável “acerto” representa o percentual obtido em cada descritor e será utilizada na criação da variável alvo do modelo. Antes da modelagem, foram verificados os valores numéricos, os dados ausentes e os códigos especiais, como BP e NP.

# %%
acerto_texto = (
    dados_conteudos["acerto"]
    .astype(str)
    .str.strip()
    .str.upper()
)

acerto_numerico = pd.to_numeric(
    dados_conteudos["acerto"]
    .astype(str)
    .str.replace(",", ".", regex=False),
    errors="coerce"
)

resumo_acerto = pd.DataFrame({
    
    "Situação": [
        "Valores numéricos válidos",
        "Valores ausentes",
        "Código BP",
        "Código NP"
    ],
    
    "Quantidade": [
        acerto_numerico.notna().sum(),
        dados_conteudos["acerto"].isna().sum(),
        (acerto_texto == "BP").sum(),
        (acerto_texto == "NP").sum()
    ]
})

resumo_acerto
# Out:
#                     Situação  Quantidade
# 0  Valores numéricos válidos      697617
# 1           Valores ausentes        1258
# 2                  Código BP       92194
# 3                  Código NP       29992

# %% [markdown]
# ### Verificação de outros valores não numéricos
#
# Além dos valores ausentes e dos códigos BP e NP, foi realizada uma verificação para identificar possíveis valores diferentes que não puderam ser convertidos para formato numérico.

# %%
outros_valores = (
    dados_conteudos.loc[
        acerto_numerico.isna(),
        "acerto"
    ]
    .astype("string")
    .str.strip()
    .str.upper()
    .fillna("AUSENTE")
    .value_counts()
)

outros_valores.head(20)
# Out:
# acerto
# BP         92194
# NP         29992
# NP/BP       7113
# -           5400
# AUSENTE     1258
# Name: count, dtype: Int64

# %% [markdown]
# A verificação identificou registros com os códigos BP, NP e NP/BP, além de valores representados por hífen e campos sem preenchimento. Como esses casos não apresentam um percentual de acerto válido, eles foram removidos da etapa de modelagem.
#
# Após o tratamento, foram mantidos somente os registros que possuíam valores numéricos na variável “acerto”.

# %%
dados_modelagem = dados_conteudos.copy()

dados_modelagem["acerto"] = pd.to_numeric(
    
    dados_modelagem["acerto"]
    .astype(str)
    .str.replace(",", ".", regex=False),
    
    errors="coerce"
)


registros_antes = dados_modelagem.shape[0]


dados_modelagem = (
    
    dados_modelagem
    .dropna(subset=["acerto"])
    .copy()
    
)

registros_depois = dados_modelagem.shape[0]


print("Registros antes da limpeza:", registros_antes)

print("Registros removidos:", registros_antes - registros_depois)

print("Registros após a limpeza:", registros_depois)
# Out:
# Registros antes da limpeza: 833574
# Registros removidos: 135957
# Registros após a limpeza: 697617

# %% [markdown]
# ### Verificação dos valores de acerto
#
# Após a remoção dos registros sem percentual válido, foi realizada uma verificação dos valores mínimos, máximos e das principais medidas estatísticas da variável “acerto”. Essa etapa permite identificar possíveis valores fora do intervalo esperado antes da criação da variável alvo.

# %%
dados_modelagem["acerto"].describe()
# Out:
# count    697617.000000
# mean         56.152890
# std          21.742006
# min           0.000000
# 25%          42.000000
# 50%          57.000000
# 75%          71.000000
# max         100.000000
# Name: acerto, dtype: float64

# %%
valores_invalidos = dados_modelagem[
    (dados_modelagem["acerto"] < 0) |
    (dados_modelagem["acerto"] > 100)
]

print(
    "Quantidade de valores fora do intervalo:",
    valores_invalidos.shape[0]
)
# Out:
# Quantidade de valores fora do intervalo: 0

# %% [markdown]
# ### Resumo da preparação dos dados
#
# As bases dos anos selecionados foram reunidas e filtradas de acordo com o objetivo do estudo. Foram mantidos os registros das redes municipal e estadual referentes ao 5º e ao 9º ano do Ensino Fundamental, nas disciplinas de Matemática e Língua Portuguesa.
#
# Também foram selecionados conteúdos considerados importantes para a aprendizagem e removidos os registros que não apresentavam percentual de acerto válido. Após o tratamento, a base utilizada na modelagem passou a possuir 697.617 registros.
#
# Com os dados organizados e verificados, a próxima etapa consiste na criação da variável alvo e na separação dos conjuntos de treino e teste.

# %% [markdown]
# ## Criação da variável alvo
#
# Para realizar a classificação, foi criada uma variável alvo com base na mediana do percentual de acerto. Os registros com desempenho abaixo da mediana foram classificados como prioridade de atenção, enquanto os resultados iguais ou superiores à mediana foram considerados como desempenho acima do ponto de referência utilizado.
#
# Esse limite foi adotado como critério estatístico para a modelagem e não representa uma classificação pedagógica oficial.

# %%
limite_acerto = dados_modelagem["acerto"].median()

print("Mediana do percentual de acerto:", limite_acerto)


dados_modelagem["alvo"] = (
    dados_modelagem["acerto"] < limite_acerto
).astype(int)


# Significado das classes:
# 0 = desempenho igual ou acima da mediana
# 1 = desempenho abaixo da mediana
# Out:
# Mediana do percentual de acerto: 57.0

# %%
distribuicao_alvo = (
    dados_modelagem["alvo"]
    .value_counts()
    .sort_index()
)

distribuicao_alvo
# Out:
# alvo
# 0    357908
# 1    339709
# Name: count, dtype: int64

# %%
(
    dados_modelagem["alvo"]
    .value_counts(normalize=True)
    .sort_index()
    .mul(100)
    .round(2)
)
# Out:
# alvo
# 0    51.3
# 1    48.7
# Name: proportion, dtype: float64

# %% [markdown]
# ### Interpretação da variável alvo
#
# A mediana do percentual de acerto foi de 57%. A partir desse valor, os registros foram divididos em duas classes: desempenho igual ou acima da mediana e desempenho abaixo da mediana.
#
# As classes apresentaram proporções próximas, com 51.3% dos registros na classe 0 e 48.7% na classe 1. Dessa forma, não foi necessário realizar procedimentos adicionais de balanceamento dos dados.

# %% [markdown]
# ## Separação dos dados em treino e teste
#
# Para avaliar o desempenho dos modelos, a base foi dividida em dois conjuntos. Foram utilizados 80% dos registros para treinamento e 20% para teste.
#
# O conjunto de treinamento será utilizado para que os modelos identifiquem padrões nos dados. Já o conjunto de teste será utilizado apenas na avaliação final, permitindo verificar o desempenho do modelo em registros que não foram utilizados durante o treinamento.

# %%
from sklearn.model_selection import train_test_split

variaveis_modelo = [
    "Ano",
    "rede",
    "etapa",
    "disciplina",
    "descricao_padronizada"
]

X = dados_modelagem[variaveis_modelo].copy()
y = dados_modelagem["alvo"].copy()

X_treino, X_teste, y_treino, y_teste = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Registros utilizados no treinamento:", X_treino.shape[0])
print("Registros utilizados no teste:", X_teste.shape[0])
# Out:
# Registros utilizados no treinamento: 558093
# Registros utilizados no teste: 139524

# %% [markdown]
# # Seção 1 — Modelo Baseline
#
# O modelo baseline foi utilizado como ponto inicial de comparação. Para essa etapa, foi utilizado o `DummyClassifier`, que realiza previsões utilizando uma estratégia simples, sem identificar relações entre as características dos dados.
#
# Foi escolhida a estratégia de prever sempre a classe mais frequente no conjunto de treinamento. Dessa forma, o resultado obtido representa um desempenho mínimo que os modelos testados posteriormente deverão superar.

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, balanced_accuracy_score


modelo_baseline = DummyClassifier(
    strategy="most_frequent"
)

modelo_baseline.fit(
    X_treino,
    y_treino
)

previsoes_baseline = modelo_baseline.predict(
    X_teste
)

acuracia_baseline = accuracy_score(
    y_teste,
    previsoes_baseline
)

acuracia_balanceada_baseline = balanced_accuracy_score(
    y_teste,
    previsoes_baseline
)

print(
    "Acurácia do baseline:",
    round(acuracia_baseline * 100, 2),
    "%"
)

print(
    "Acurácia balanceada:",
    round(acuracia_balanceada_baseline * 100, 2),
    "%"
)
# Out:
# Acurácia do baseline: 51.3 %
# Acurácia balanceada: 50.0 %

# %% [markdown]
# # Seção 2 — Experimentos
#
# Nesta seção serão avaliados diferentes modelos de classificação. Para comparar os resultados, será utilizada a validação cruzada, permitindo observar tanto o desempenho médio quanto a variação dos resultados entre diferentes divisões dos dados.
#
# Como as variáveis rede, etapa, disciplina e descritor são categóricas, foi utilizada a técnica One-Hot Encoding para convertê-las em informações numéricas sem criar uma relação de ordem entre as categorias.

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold, cross_val_score

variaveis_categoricas = [
    "rede",
    "etapa",
    "disciplina",
    "descricao_padronizada"
]
preprocessador = ColumnTransformer(
    transformers=[
        (
            "categoricas",
            OneHotEncoder(
                handle_unknown="ignore"
            ),
            variaveis_categoricas
        )
    ],
    remainder="passthrough"
)

validacao_cruzada = StratifiedKFold(
    n_splits=3,
    shuffle=True,
    random_state=42
)

print("Preparação dos experimentos concluída!")
# Out:
# Preparação dos experimentos concluída!

# %% [markdown]
# ## Experimento 1 — Regressão Logística
#
# A Regressão Logística foi escolhida como primeiro modelo por ser uma abordagem simples, rápida e fácil de interpretar. Apesar do nome, ela é utilizada em problemas de classificação e calcula a probabilidade de cada registro pertencer a uma das classes.
#
# O modelo foi configurado com até 1.000 iterações. Seu desempenho foi avaliado por meio de validação cruzada com três divisões, utilizando a acurácia balanceada como métrica.

# %%
from sklearn.linear_model import LogisticRegression

regressao_logistica = LogisticRegression(
    max_iter=1000,
    random_state=42
)

pipeline_logistica = Pipeline(
    steps=[
        ("preprocessamento", preprocessador),
        ("modelo", regressao_logistica)
    ]
)

resultado_logistica = cross_val_score(
    pipeline_logistica,
    X_treino,
    y_treino,
    cv=validacao_cruzada,
    scoring="balanced_accuracy",
    n_jobs=-1
)

media_logistica = resultado_logistica.mean()
desvio_logistica = resultado_logistica.std()

print(
    "Resultados de cada divisão:",
    resultado_logistica.round(4)
)

print(
    "Média da acurácia balanceada:",
    round(media_logistica * 100, 2),
    "%"
)

print(
    "Desvio padrão:",
    round(desvio_logistica * 100, 2),
    "%"
)
# Out:
# /Users/luangomes/Code/projeto-integrado-simave-mg/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/luangomes/Code/projeto-integrado-simave-mg/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Resultados de cada divisão: [0.7399 0.7394 0.7403]
# Média da acurácia balanceada: 73.99 %
# Desvio padrão: 0.04 %
# /Users/luangomes/Code/projeto-integrado-simave-mg/.venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### Interpretação da Regressão Logística
#
# A Regressão Logística apresentou acurácia balanceada média de 73,99%, superando o resultado obtido pelo modelo baseline. Isso indica que o modelo conseguiu identificar relações entre as características dos registros e as classes de desempenho.
#
# O desvio padrão foi de apenas 0,04%, mostrando que os resultados permaneceram semelhantes nas três divisões da validação cruzada. Dessa forma, o modelo apresentou desempenho estável e superior ao modelo utilizado como referência.

# %% [markdown]
# ## Experimento 2 — Árvore de Decisão
#
# A Árvore de Decisão foi escolhida por ser um modelo capaz de identificar relações mais complexas entre as características dos dados. Seu funcionamento ocorre por meio da criação de regras sucessivas que dividem os registros de acordo com as informações disponíveis.
#
# Para reduzir o risco de o modelo memorizar excessivamente os dados de treinamento, foi limitada a profundidade máxima da árvore e definida uma quantidade mínima de registros em cada folha. O desempenho foi avaliado utilizando a mesma validação cruzada e a mesma métrica aplicada no experimento anterior.

# %%
from sklearn.tree import DecisionTreeClassifier

arvore_decisao = DecisionTreeClassifier(
    max_depth=15,
    min_samples_leaf=50,
    random_state=42
)

pipeline_arvore = Pipeline(
    steps=[
        ("preprocessamento", preprocessador),
        ("modelo", arvore_decisao)
    ]
)

resultado_arvore = cross_val_score(
    pipeline_arvore,
    X_treino,
    y_treino,
    cv=validacao_cruzada,
    scoring="balanced_accuracy",
    n_jobs=-1
)

media_arvore = resultado_arvore.mean()

desvio_arvore = resultado_arvore.std()

print(
    "Resultados de cada divisão:",
    resultado_arvore.round(4)
)

print(
    "Média da acurácia balanceada:",
    round(media_arvore * 100, 2),
    "%"
)

print(
    "Desvio padrão:",
    round(desvio_arvore * 100, 2),
    "%"
)
# Out:
# Resultados de cada divisão: [0.7403 0.741  0.7332]
# Média da acurácia balanceada: 73.82 %
# Desvio padrão: 0.35 %

# %% [markdown]
# ### Interpretação da Árvore de Decisão
#
# A Árvore de Decisão apresentou acurácia balanceada média de 73,82%, resultado muito próximo ao obtido pela Regressão Logística. A diferença entre os dois modelos foi de apenas 0,17.
#
# O desvio padrão foi de 0,35%, indicando que o desempenho apresentou uma pequena variação entre as divisões da validação cruzada. Mesmo assim, o modelo permaneceu estável e superou com folga o resultado do baseline.

# %% [markdown]
# ## Experimento 3 — Random Forest
#
# A Random Forest combina várias árvores de decisão para realizar as classificações. Cada árvore analisa diferentes partes dos dados e, ao final, o resultado é definido pela combinação das previsões realizadas.
#
# Essa abordagem pode reduzir alguns erros encontrados em uma única árvore e melhorar a capacidade de identificar padrões mais complexos. Para evitar um processamento excessivo, foram utilizadas 100 árvores com profundidade máxima limitada.

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier(
    n_estimators=100,
    max_depth=20,
    min_samples_leaf=50,
    random_state=42,
    n_jobs=-1
)

pipeline_random_forest = Pipeline(
    steps=[
        ("preprocessamento", preprocessador),
        ("modelo", random_forest)
    ]
)

resultado_random_forest = cross_val_score(
    pipeline_random_forest,
    X_treino,
    y_treino,
    cv=validacao_cruzada,
    scoring="balanced_accuracy",
    n_jobs=1
)

media_random_forest = resultado_random_forest.mean()

desvio_random_forest = resultado_random_forest.std()

print(
    "Resultados de cada divisão:",
    resultado_random_forest.round(4)
)

print(
    "Média da acurácia balanceada:",
    round(media_random_forest * 100, 2),
    "%"
)

print(
    "Desvio padrão:",
    round(desvio_random_forest * 100, 2),
    "%"
)
# Out:
# Resultados de cada divisão: [0.753  0.7535 0.7537]
# Média da acurácia balanceada: 75.34 %
# Desvio padrão: 0.03 %

# %% [markdown]
# ### Interpretação da Random Forest
#
# A Random Forest apresentou acurácia balanceada média de 75,34%, sendo o melhor resultado entre os modelos avaliados. O modelo superou a Regressão Logística e a Árvore de Decisão, além de apresentar desempenho bastante superior ao baseline.
#
# O desvio padrão foi de 0,03%, indicando pouca variação entre as divisões da validação cruzada. Dessa forma, o modelo apresentou desempenho estável e demonstrou maior capacidade de identificar padrões relacionados às classes de desempenho.

# %% [markdown]
# ## Comparação dos experimentos
#
# A tabela a seguir apresenta os resultados obtidos pelos três modelos. A comparação considera a média da acurácia balanceada, o desvio padrão da validação cruzada, os hiperparâmetros utilizados e a justificativa para a escolha de cada abordagem.

# %%
comparacao_modelos = pd.DataFrame({

    "Modelo": [
        "Regressão Logística",
        "Árvore de Decisão",
        "Random Forest"
    ],

    "Hiperparâmetros": [
        "max_iter=1000",
        "max_depth=15; min_samples_leaf=50",
        "n_estimators=100; max_depth=20; min_samples_leaf=50"
    ],

    "Média CV (%)": [
        round(media_logistica * 100, 2),
        round(media_arvore * 100, 2),
        round(media_random_forest * 100, 2)
    ],

    "Desvio padrão (%)": [
        round(desvio_logistica * 100, 2),
        round(desvio_arvore * 100, 2),
        round(desvio_random_forest * 100, 2)
    ],

    "Justificativa": [
        "Modelo simples e de fácil interpretação",
        "Permite identificar relações e regras mais complexas",
        "Combina várias árvores e pode melhorar a estabilidade das previsões"
    ]
})

comparacao_modelos
# Out:
#                 Modelo                                      Hiperparâmetros  \
# 0  Regressão Logística                                        max_iter=1000
# 1    Árvore de Decisão                    max_depth=15; min_samples_leaf=50
# 2        Random Forest  n_estimators=100; max_depth=20; min_samples_leaf=50
#
#    Média CV (%)  Desvio padrão (%)  \
# 0         73.99               0.04
# 1         73.82               0.35
# 2         75.34               0.03
#
#                                                          Justificativa
# 0                              Modelo simples e de fácil interpretação
# 1                 Permite identificar relações e regras mais complexas
# 2  Combina várias árvores e pode melhorar a estabilidade das previsões

# %% [markdown]
# # Seção 3 — Modelo final
#
# A Random Forest foi escolhida como modelo final por apresentar a maior média de acurácia balanceada durante a validação cruzada, alcançando 75,34%. O modelo também apresentou baixo desvio padrão, indicando pouca variação entre as diferentes divisões dos dados.
#
# Os hiperparâmetros utilizados foram 100 árvores, profundidade máxima igual a 20 e quantidade mínima de 50 registros em cada folha. Após a escolha, o modelo foi treinado utilizando todo o conjunto de treinamento e avaliado no conjunto de teste, que não havia sido utilizado durante os experimentos.

# %%
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    classification_report
)

pipeline_random_forest.fit(
    X_treino,
    y_treino
)

previsoes_final = pipeline_random_forest.predict(
    X_teste
)

probabilidades_final = pipeline_random_forest.predict_proba(
    X_teste
)[:, 1]

acuracia_final = accuracy_score(
    y_teste,
    previsoes_final
)

acuracia_balanceada_final = balanced_accuracy_score(
    y_teste,
    previsoes_final
)


print(
    "Acurácia no conjunto de teste:",
    round(acuracia_final * 100, 2),
    "%"
)

print(
    "Acurácia balanceada no conjunto de teste:",
    round(acuracia_balanceada_final * 100, 2),
    "%"
)
# Out:
# Acurácia no conjunto de teste: 75.44 %
# Acurácia balanceada no conjunto de teste: 75.44 %

# %% [markdown]
# ## Relatório de classificação
#
# O relatório de classificação apresenta métricas específicas para cada classe. A precisão indica a proporção de previsões corretas entre os registros classificados em determinada categoria. O recall mostra a capacidade do modelo de encontrar os registros que realmente pertencem à classe, enquanto o F1-score representa um equilíbrio entre precisão e recall.

# %%
relatorio_classificacao = classification_report(
    y_teste,
    previsoes_final,
    labels=[0, 1],
    target_names=[
        "Igual ou acima da mediana",
        "Abaixo da mediana"
    ],
    output_dict=True
)

relatorio_classificacao = pd.DataFrame(
    relatorio_classificacao
).transpose()

relatorio_classificacao.round(3)
# Out:
#                            precision  recall  f1-score     support
# Igual ou acima da mediana      0.763   0.756     0.759   71582.000
# Abaixo da mediana              0.745   0.753     0.749   67942.000
# accuracy                       0.754   0.754     0.754       0.754
# macro avg                      0.754   0.754     0.754  139524.000
# weighted avg                   0.755   0.754     0.754  139524.000

# %% [markdown]
# ### Interpretação do desempenho do modelo final
#
# No conjunto de teste, a Random Forest apresentou acurácia de 75,44% e acurácia balanceada de 75,44%. Esses valores ficaram próximos ao resultado obtido durante a validação cruzada, indicando que o modelo manteve um desempenho semelhante ao analisar registros que não foram utilizados no treinamento.
#
# O relatório de classificação também apresentou resultados próximos entre as duas classes. A classe referente ao desempenho igual ou acima da mediana obteve F1-score de 75,9%, enquanto a classe de desempenho abaixo da mediana apresentou F1-score de 74,9%.
#
# De forma geral, o modelo demonstrou capacidade semelhante para identificar as duas categorias, sem apresentar uma diferença muito elevada entre os resultados das classes.

# %% [markdown]
# ## Matriz de confusão
#
# A matriz de confusão permite visualizar a quantidade de previsões corretas e incorretas realizadas pelo modelo. Dessa forma, é possível observar quantos registros foram classificados corretamente em cada categoria e quais tipos de erro ocorreram com maior frequência.

# %%
import matplotlib.pyplot as plt

from sklearn.metrics import (
    confusion_matrix,
    ConfusionMatrixDisplay
)

matriz_confusao = confusion_matrix(
    y_teste,
    previsoes_final,
    labels=[0, 1]
)

fig, ax = plt.subplots(
    figsize=(8, 6)
)

grafico_matriz = ConfusionMatrixDisplay(
    confusion_matrix=matriz_confusao,
    display_labels=[
        "Igual ou acima da mediana",
        "Abaixo da mediana"
    ]
)

grafico_matriz.plot(
    ax=ax,
    values_format="d",
    colorbar=False
)

plt.title(
    "Matriz de Confusão — Random Forest"
)

plt.tight_layout()

plt.show()

# %% [markdown]
# A matriz de confusão mostrou que o modelo classificou corretamente 54.083 registros com desempenho igual ou acima da mediana e 51.176 registros abaixo da mediana. Também foram observados 17.499 casos classificados incorretamente como abaixo da mediana e 16.766 casos que estavam abaixo da mediana, mas foram classificados como iguais ou superiores. De forma geral, o modelo apresentou desempenho semelhante nas duas classes, embora ainda tenha ocorrido uma quantidade considerável de erros.

# %% [markdown]
# ## Curva ROC
#
# A curva ROC permite avaliar a capacidade do modelo de diferenciar as duas classes em diferentes limites de decisão. Quanto mais próxima a curva estiver do canto superior esquerdo, melhor é a capacidade de separação do modelo.
#
# A área sob a curva, chamada AUC, varia de 0 a 1. Valores próximos de 0,5 indicam um desempenho semelhante ao acaso, enquanto valores mais próximos de 1 representam uma melhor capacidade de distinguir as classes.

# %%
from sklearn.metrics import (
    roc_curve,
    roc_auc_score
)

# Cálculo da curva ROC

taxa_falso_positivo, taxa_verdadeiro_positivo, limites = roc_curve(
    y_teste,
    probabilidades_final
)

# Cálculo da área sob a curva

auc = roc_auc_score(
    y_teste,
    probabilidades_final
)

# Criação do gráfico

plt.figure(
    figsize=(8, 6)
)

plt.plot(
    taxa_falso_positivo,
    taxa_verdadeiro_positivo,
    label=f"Random Forest — AUC = {auc:.3f}"
)

plt.plot(
    [0, 1],
    [0, 1],
    linestyle="--",
    label="Classificação ao acaso"
)

plt.xlabel(
    "Taxa de falsos positivos"
)

plt.ylabel(
    "Taxa de verdadeiros positivos"
)

plt.title(
    "Curva ROC — Random Forest"
)

plt.legend()

plt.tight_layout()

plt.show()

print(
    "Área sob a curva ROC:",
    round(auc, 3)
)
# Out:
# Área sob a curva ROC: 0.831

# %% [markdown]
# ### Interpretação da curva ROC
#
# A Random Forest apresentou uma área sob a curva ROC de 0,831. Esse resultado indica que o modelo possui boa capacidade de diferenciar os registros abaixo da mediana daqueles com desempenho igual ou superior à mediana.
#
# A curva permaneceu acima da linha que representa uma classificação ao acaso, mostrando que o modelo conseguiu identificar padrões relevantes nos dados. Embora o resultado não seja perfeito, ele demonstra uma capacidade satisfatória de separação entre as duas classes.

# %% [markdown]
# # Seção 4 — Análise dos erros
#
# Nesta seção serão analisados os registros classificados incorretamente pelo modelo. O objetivo é identificar em quais etapas, disciplinas, anos e conteúdos os erros ocorreram com maior frequência.
#
# Também serão comparados os dois tipos de erro: registros abaixo da mediana classificados como iguais ou superiores e registros iguais ou superiores classificados como abaixo da mediana.

# %%
analise_erros = X_teste.copy()

analise_erros["classe_real"] = y_teste

analise_erros["classe_prevista"] = previsoes_final

analise_erros["acerto_real"] = dados_modelagem.loc[
    X_teste.index,
    "acerto"
]

analise_erros["resultado"] = (
    analise_erros["classe_real"]
    ==
    analise_erros["classe_prevista"]
)

erros_modelo = analise_erros[
    analise_erros["resultado"] == False
].copy()

print(
    "Total de registros no teste:",
    analise_erros.shape[0]
)

print(
    "Quantidade de classificações corretas:",
    analise_erros["resultado"].sum()
)

print(
    "Quantidade de erros:",
    erros_modelo.shape[0]
)

print(
    "Taxa de erro:",
    round(
        erros_modelo.shape[0]
        /
        analise_erros.shape[0]
        *
        100,
        2
    ),
    "%"
)
# Out:
# Total de registros no teste: 139524
# Quantidade de classificações corretas: 105259
# Quantidade de erros: 34265
# Taxa de erro: 24.56 %

# %% [markdown]
# ## Tipos de erro encontrados
#
# Os erros foram separados de acordo com a classe real e a classificação realizada pelo modelo. Essa divisão permite identificar se o modelo indicou uma possível necessidade de atenção quando ela não existia ou se deixou de identificar um registro que apresentava desempenho abaixo da mediana.
#
# No contexto do estudo, o segundo caso merece maior atenção, pois representa situações em que um resultado abaixo da mediana foi classificado pelo modelo como igual ou superior.

# %%
erros_modelo["tipo_erro"] = "Não identificado"

erros_modelo.loc[
    (erros_modelo["classe_real"] == 0)
    &
    (erros_modelo["classe_prevista"] == 1),
    "tipo_erro"
] = "Igual ou acima classificado como abaixo"


erros_modelo.loc[
    (erros_modelo["classe_real"] == 1)
    &
    (erros_modelo["classe_prevista"] == 0),
    "tipo_erro"
] = "Abaixo classificado como igual ou acima"


tipos_erros = (
    erros_modelo["tipo_erro"]
    .value_counts()
    .rename_axis("Tipo de erro")
    .reset_index(name="Quantidade")
)

tipos_erros["Percentual dos erros (%)"] = (
    tipos_erros["Quantidade"]
    /
    tipos_erros["Quantidade"].sum()
    *
    100
).round(2)

tipos_erros
# Out:
#                               Tipo de erro  Quantidade  \
# 0  Igual ou acima classificado como abaixo       17499
# 1  Abaixo classificado como igual ou acima       16766
#
#    Percentual dos erros (%)
# 0                     51.07
# 1                     48.93

# %% [markdown]
# ### Interpretação dos tipos de erro
#
# Os dois tipos de erro apresentaram quantidades próximas. Em 51,07% dos casos, registros que estavam abaixo da mediana foram classificados como iguais ou superiores. Nos outros 48,93%, registros iguais ou acima da mediana foram classificados como abaixo.
#
# O primeiro tipo merece maior atenção, pois representa situações em que o modelo deixou de identificar um resultado que poderia indicar necessidade de acompanhamento. Mesmo assim, a diferença entre os dois tipos foi pequena, mostrando que os erros ocorreram de forma relativamente equilibrada.

# %% [markdown]
# ## Erros por disciplina
#
# Para verificar se o desempenho do modelo apresentou diferenças entre as disciplinas, foi calculada a quantidade de registros analisados, o número de classificações incorretas e a taxa de erro em Matemática e Língua Portuguesa.

# %%
erros_por_disciplina = (
    analise_erros
    .groupby("disciplina")
    .agg(
        Total_de_registros=("resultado", "size"),
        Quantidade_de_erros=(
            "resultado",
            lambda valores: (~valores).sum()
        )
    )
    .reset_index()
)

erros_por_disciplina["Taxa de erro (%)"] = (
    erros_por_disciplina["Quantidade_de_erros"]
    /
    erros_por_disciplina["Total_de_registros"]
    *
    100
).round(2)

erros_por_disciplina
# Out:
#           disciplina  Total_de_registros  Quantidade_de_erros  \
# 0  LINGUA PORTUGUESA               48189                13383
# 1         MATEMATICA               91335                20882
#
#    Taxa de erro (%)
# 0             27.77
# 1             22.86

# %% [markdown]
# ### Interpretação dos erros por disciplina
#
# A análise mostrou que a taxa de erro foi maior em Língua Portuguesa, com 27,77%, enquanto Matemática apresentou taxa de 22,86%.
#
# Esse resultado indica que o modelo encontrou maior dificuldade para identificar os padrões relacionados aos conteúdos de Língua Portuguesa. Uma possível explicação é que habilidades de leitura e interpretação podem apresentar maior variação entre os descritores e os anos analisados.

# %% [markdown]
# ## Erros por etapa de ensino
#
# Também foi analisada a taxa de erro em cada etapa de ensino. O objetivo foi verificar se o modelo apresentou maior dificuldade nos registros do 5º ou do 9º ano do Ensino Fundamental.

# %%
erros_por_etapa = (
    analise_erros
    .groupby("etapa")
    .agg(
        Total_de_registros=("resultado", "size"),
        Quantidade_de_erros=(
            "resultado",
            lambda valores: (~valores).sum()
        )
    )
    .reset_index()
)

erros_por_etapa["Taxa de erro (%)"] = (
    erros_por_etapa["Quantidade_de_erros"]
    /
    erros_por_etapa["Total_de_registros"]
    *
    100
).round(2)

erros_por_etapa
# Out:
#        etapa  Total_de_registros  Quantidade_de_erros  Taxa de erro (%)
# 0  5º ANO EF               84505                21646             25.62
# 1  9º ANO EF               55019                12619             22.94

# %% [markdown]
# ### Interpretação dos erros por etapa
#
# A taxa de erro foi de 25,62% para o 5º ano e de 22,94% para o 9º ano. Apesar de os resultados serem próximos, o modelo apresentou uma dificuldade um pouco maior na classificação dos registros do 5º ano.
#
# De forma geral, o desempenho permaneceu semelhante entre as duas etapas, sem uma diferença muito elevada na quantidade proporcional de erros.

# %% [markdown]
# ## Erros por ano
#
# A taxa de erro também foi analisada em cada ano disponível na base. Essa comparação permite verificar se o modelo apresentou maior dificuldade em determinados períodos.

# %%
erros_por_ano = (
    analise_erros
    .groupby("Ano")
    .agg(
        Total_de_registros=("resultado", "size"),
        Quantidade_de_erros=(
            "resultado",
            lambda valores: (~valores).sum()
        )
    )
    .reset_index()
)

erros_por_ano["Taxa de erro (%)"] = (
    erros_por_ano["Quantidade_de_erros"]
    /
    erros_por_ano["Total_de_registros"]
    *
    100
).round(2)

erros_por_ano
# Out:
#     Ano  Total_de_registros  Quantidade_de_erros  Taxa de erro (%)
# 0  2016               29460                 7263             24.65
# 1  2019               25893                 5627             21.73
# 2  2021                7058                 1916             27.15
# 3  2022               24161                 6400             26.49
# 4  2023               29412                 7309             24.85
# 5  2024               23540                 5750             24.43

# %% [markdown]
# ### Interpretação dos erros por ano
#
# A taxa de erro apresentou variações entre os anos analisados. O maior valor foi observado em 2021, com 27,15%. Já o menor percentual ocorreu em 2019, com 21,73%.
#
# Essas diferenças mostram que o modelo apresentou maior dificuldade para identificar os padrões presentes em alguns anos. Isso pode estar relacionado a mudanças nas características dos dados, nos conteúdos avaliados ou na distribuição dos resultados ao longo do período.

# %%
verificacao_anos = pd.DataFrame({

    "Após filtro inicial":
    dados_filtrados["Ano"]
    .value_counts()
    .sort_index(),

    "Após seleção dos conteúdos":
    dados_conteudos["Ano"]
    .value_counts()
    .sort_index(),

    "Após limpeza do acerto":
    dados_modelagem["Ano"]
    .value_counts()
    .sort_index()

}).fillna(0).astype(int)

verificacao_anos
# Out:
#       Após filtro inicial  Após seleção dos conteúdos  Após limpeza do acerto
# Ano
# 2016               573496                      159852                  146967
# 2019               512703                      141601                  128527
# 2021               231873                       59396                   35440
# 2022               493236                      135523                  121067
# 2023               539162                      165254                  146903
# 2024               502827                      171948                  118713

# %% [markdown]
# ### Disponibilidade dos dados após os filtros
#
# As bases de 2015 e 2017 foram carregadas durante a preparação dos dados. Entretanto, após a aplicação dos filtros definidos para o estudo, não permaneceram registros desses anos.
#
# Dessa forma, a etapa de modelagem utilizou dados referentes aos anos de 2016, 2019, 2021, 2022, 2023 e 2024. Essa diferença ocorreu devido às características e à disponibilidade dos registros em cada edição das avaliações.

# %% [markdown]
# ## Conteúdos com maior taxa de erro
#
# Por fim, foram analisados os conteúdos em que o modelo apresentou maior dificuldade. Para evitar conclusões baseadas em poucos registros, foram considerados apenas os conteúdos com pelo menos 200 observações no conjunto de teste.

# %%
analise_erros["conteudo"] = dados_modelagem.loc[
    X_teste.index,
    "descritor_descricao"
]

erros_por_conteudo = (
    analise_erros
    .groupby(
        [
            "disciplina",
            "descricao_padronizada"
        ]
    )
    .agg(
        Conteudo=(
            "conteudo",
            "first"
        ),
        
        Total_de_registros=(
            "resultado",
            "size"
        ),
        
        Quantidade_de_erros=(
            "resultado",
            lambda valores: (~valores).sum()
        )
    )
    .reset_index()
)

erros_por_conteudo["Taxa de erro (%)"] = (
    erros_por_conteudo["Quantidade_de_erros"]
    /
    erros_por_conteudo["Total_de_registros"]
    *
    100
).round(2)

conteudos_maior_erro = (
    erros_por_conteudo[
        erros_por_conteudo["Total_de_registros"] >= 200
    ]
    .sort_values(
        "Taxa de erro (%)",
        ascending=False
    )
    .head(10)
    [
        [
            "disciplina",
            "Conteudo",
            "Total_de_registros",
            "Quantidade_de_erros",
            "Taxa de erro (%)"
        ]
    ]
    .reset_index(drop=True)
)

conteudos_maior_erro
# Out:
#           disciplina  \
# 0         MATEMATICA
# 1         MATEMATICA
# 2         MATEMATICA
# 3         MATEMATICA
# 4  LINGUA PORTUGUESA
# 5         MATEMATICA
# 6         MATEMATICA
# 7         MATEMATICA
# 8  LINGUA PORTUGUESA
# 9         MATEMATICA
#
#                                                                                                                     Conteudo  \
# 0             Associar informações apresentadas em listas e/ou tabelas simples aos gráficos que as representam e vice-versa.
# 1   Efetuar cálculos com números inteiros, envolvendo as operações (adição, subtração, multiplicação, divisão, potenciação).
# 2  Resolver problema com números racionais envolvendo as operações (adição, subtração, multiplicação, divisão, potenciação).
# 3                      UTILIZAR NUMEROS RACIONAIS ENVOLVENDO DIFERENTES SIGNIFICADOS DAS OPERACOES NA RESOLUCAO DE PROBLEMAS
# 4                                                                        Distinguir um fato da opinião relativa a esse fato.
# 5                                   IDENTIFICAR FRACAO COMO REPRESENTACAO QUE PODE ESTAR ASSOCIADA A DIFERENTES SIGNIFICADOS
# 6                            Identificar a localização de números racionais representados na forma decimal na reta numérica.
# 7                                                           Identificar a localização de números racionais na reta numérica.
# 8                                                                              Inferir uma informação implícita em um texto.
# 9        UTILIZAR NUMEROS RACIONAIS EXPRESSOS NA FORMA DECIMAL ENVOLVENDO MULTIPLICACAO OU DIVISAO NA RESOLUCAO DE PROBLEMAS
#
#    Total_de_registros  Quantidade_de_erros  Taxa de erro (%)
# 0                 596                  284             47.65
# 1                 594                  282             47.47
# 2                 639                  293             45.85
# 3                3360                 1435             42.71
# 4                1404                  596             42.45
# 5                1128                  470             41.67
# 6                 776                  317             40.85
# 7                 625                  253             40.48
# 8                1441                  555             38.51
# 9                4982                 1889             37.92

# %% [markdown]
# ### Interpretação dos erros por conteúdo
#
# Os maiores percentuais de erro foram observados em conteúdos relacionados à distinção entre fato e opinião, interpretação de informações, frações e operações com números naturais e racionais.
#
# Dos 5 conteúdos com maior taxa de erro, 4 são de Matemática. Incluindo o conteúdo com maior taxa de erro, “Associar informações apresentadas em listas e/ou tabelas simples aos gráficos que as representam e vice-versa.”, com 47,65%. Além desse, na disciplina, destacaram-se conteúdos envolvendo frações, multiplicação, divisão e números racionais.
#
# Esses resultados indicam que o modelo apresentou maior dificuldade para classificar registros relacionados a essas habilidades. No entanto, isso não significa, necessariamente, que esses foram os conteúdos com menor desempenho dos estudantes, mas sim que os padrões disponíveis nos dados foram menos claros para o modelo.

# %% [markdown]
# # Seção 5 — Limitações
#
# Apesar dos resultados obtidos, o modelo apresenta algumas limitações. A classificação foi criada utilizando a mediana do percentual de acerto, igual a 57%, como ponto de separação entre as classes. Esse valor foi utilizado como critério estatístico e não representa uma classificação pedagógica oficial.
#
# O modelo utilizou apenas as informações disponíveis nas bases analisadas, como ano, etapa, disciplina e conteúdo avaliado. Outros fatores que podem influenciar o desempenho dos estudantes, como frequência escolar, condições socioeconômicas, infraestrutura da escola, formação dos professores e participação dos alunos, não estavam disponíveis.
#
# Também foram removidos registros sem percentual de acerto válido, incluindo os códigos BP, NP e NP/BP. Além disso, após a aplicação dos filtros definidos para o estudo, as bases de 2015 e 2017 não permaneceram na etapa de modelagem.
#
# Por fim, o modelo apresentou desempenho satisfatório, mas ainda realizou classificações incorretas em parte dos registros. Dessa forma, seus resultados devem ser utilizados como apoio à análise e à tomada de decisão, não substituindo a avaliação realizada por profissionais da área educacional.
